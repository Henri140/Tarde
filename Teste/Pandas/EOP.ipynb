# %%
import pandas as pd

df = pd.read_csv("vinhos.csv")

print(df.head(),df.tail(2))

print(df.describe(percentiles=[0.33, 0.66, 1.00, 0.22]))

print(df.info(show_counts=True, memory_usage=True, verbose=True))

print(df.shape)

df2=df.copy()
df2.loc[2:5,'value_usd']=None

print(df2.head(7))


print(df2.isnull().sum().sum())
# Out:
#    id               vinho     origem  preco  avaliacao
# 0   1  Cabernet Sauvignon     Franca    120        4.5
# 1   2              Merlot     Italia     90        4.2
# 2   3              Malbec  Argentina     80        4.4
# 3   4          Chardonnay        EUA    110        4.3
# 4   5     Sauvignon Blanc      Chile     70        4.1    id        vinho   origem  preco  avaliacao
# 8   9    Zinfandel      EUA    100        4.0
# 9  10  Tempranillo  Espanha     75        4.1
#              id       preco  avaliacao
# count  10.00000   10.000000  10.000000
# mean    5.50000   97.500000   4.270000
# std     3.02765   24.065882   0.188856
# min     1.00000   70.000000   4.000000
# 22%     2.98000   79.900000   4.100000
# 33%     3.97000   84.850000   4.197000
# 66%     6.94000   99.700000   4.300000
# 100%   10.00000  150.000000   4.600000
# max    10.00000  150.000000   4.600000
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         10 non-null     int64
#  1   vinho      10 non-null     str
#  2   origem     10 non-null     str
#  3   preco      10 non-null     int64
#  4   avaliacao  10 non-null     float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 532.0 bytes
# None
# (10, 5)
#    id               vinho     origem  preco  avaliacao value_usd
# 0   1  Cabernet Sauvignon     Franca    120        4.5       NaN
# 1   2              Merlot     Italia     90        4.2       NaN
# 2   3              Malbec  Argentina     80        4.4      None
# 3   4          Chardonnay        EUA    110        4.3      None
# 4   5     Sauvignon Blanc      Chile     70        4.1      None
# 5   6          Pinot Noir     Franca    150        4.6      None
# 6   7               Syrah  Australia     95        4.2       NaN
# 10
