# %%
num=(0,1,2,3)
print(num[1])
# Out:
# 1

# %%
st=("Alfa", "Beta", "Gama", "Delta")
num=(0,1,2,3)
print(num[2], st[3])
# Out:
# 2 Delta

# %%
num=(5,10,15,20)
num_l=list(num)
num_l.append(25)
num=tuple(num_l)
print(num)
# Out:
# (5, 10, 15, 20, 25)
