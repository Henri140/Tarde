# %%
def Curso_FIC_Senai(curso):
    nome='Pedro'
    idade=20
    print(f'Bem-vindo {nome}, agora aos {idade} você ingressa no Curso FIC Senai')

Curso_FIC_Senai(Curso_FIC_Senai)
# Out:
# Bem-vindo Pedro, agora aos 20 você ingressa no Curso FIC Senai

# %%
def par_ou_impar(num):
    num=int(input(f'Digite o número: '))
    if num%2==0:
        print(f'{num} é par')
    else:
        print(f'{num} é impar')

par_ou_impar(2)
# Out:
# 10 é par

# %%
def temp ():
    f=float(input(f'Digite a temperatura(em Fahreint): '))
    tempC=(f-32)* 5/9
    tempK=(f-32)* 5/9+273,15
    print(f'Em Celsius:{tempC},Em Kelvin:{tempK}')

temp()
# Out:
# Em Celsius:-573.3333333333334,Em Kelvin:(-300.33333333333337, 15)

# %%
def tamanho_palavra():
    pl=input(f'Digite: ')
    print(f'Seu texto contém {len(pl)} palavras')

tamanho_palavra()
# Out:
# Seu texto contém 16 palavras
