# %%
aluno={'nome':'Roberto','idade':19,'curso':'DS'}
al_n={'nota':8}
aluno.update(al_n)
print(aluno)
# Out:
# {'nome': 'Roberto', 'idade': 19, 'curso': 'DS', 'nota': 8}

# %%
mercado = {
'pd1':{'Nome':'Alvejante','Preço':24.99},
'pd2':{'Nome':'Detergente','Preço':5.59},
'pd3':{'Nome':'Sabão em pó','Preço':22.60}
}


print(mercado['pd1']['Preço'])
# Out:
# 24.99

# %%
mercado = {
'pd1':{'Nome':'Alvejante','Preço':24.99},
'pd2':{'Nome':'Detergente','Preço':5.59},
'pd3':{'Nome':'Sabão em pó','Preço':22.60}
}

mercado.pop('pd2')

print(mercado)
# Out:
# {'pd1': {'Nome': 'Alvejante', 'Preço': 24.99}, 'pd3': {'Nome': 'Sabão em pó', 'Preço': 22.6}}
