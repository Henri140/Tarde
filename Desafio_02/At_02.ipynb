# %%
lv1={"titulo": "Dom Casmurro", "autor": "Machado de Assis", "ano": 1899}
lv2={"titulo": "Memórias Póstumas de Brás Cubas", "autor": "Machado de Assis", "ano": 1881}
lv3={"titulo": "O Alienista", "autor": "Machado de Assis", "ano": 1882}
biblio=[lv1, lv2, lv3]

for livro in biblio:
    print(f"Título: {livro['titulo']}, Autor: {livro['autor']}, Ano: {livro['ano']}")
# Out:
# Título: Dom Casmurro, Autor: Machado de Assis, Ano: 1899
# Título: Memórias Póstumas de Brás Cubas, Autor: Machado de Assis, Ano: 1881
# Título: O Alienista, Autor: Machado de Assis, Ano: 1882
